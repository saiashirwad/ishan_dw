# %%
import pandas as pd

# %%
cd GTFS\ -\ Melbourne\ Train\ Information
# Out:
# /home/sai/mishra/A3/GTFS - Melbourne Train Information

# %%
agency = pd.read_csv("agency.txt")
calendar_dates = pd.read_csv("calendar_dates.txt")
calendar = pd.read_csv("calendar.txt")
routes = pd.read_csv("routes.txt")
shapes = pd.read_csv("shapes.txt")
stops = pd.read_csv("stops.txt")
stop_times = pd.read_csv("stop_times.txt")
trips = pd.read_csv("trips.txt")

# %%
print(list(calendar.columns))
print(list(routes.columns))
print(list(shapes.columns))
print(list(stops.columns))
print(list(stop_times.columns))
print(list(trips.columns))
# Out:
# ['service_id', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday', 'sunday', 'start_date', 'end_date']
# ['route_id', 'agency_id', 'route_short_name', 'route_long_name', 'route_type']
# ['shape_id', 'shape_pt_lat', 'shape_pt_lon', 'shape_pt_sequence', 'shape_dist_traveled']
# ['stop_id', 'stop_name', 'stop_short_name', 'stop_lat', 'stop_lon']
# ['trip_id', 'arrival_time', 'departure_time', 'stop_id', 'stop_sequence', 'stop_headsign', 'pickup_type', 'drop_off_type', 'shape_dist_traveled']
# ['route_id', 'service_id', 'trip_id', 'shape_id', 'trip_headsign', 'direction_id']

# %%
# handling cases where the hour in time > 24
for index in stop_times[stop_times.arrival_time.str.match("24:\d{1,2}:\d{1,2}")].index:
    time = stop_times.loc[index, 'arrival_time'].split(":")
    time = ":".join(["00", time[1], time[2]])
    stop_times.loc[index, 'arrival_time'] = time


for index in stop_times[stop_times.departure_time.str.match("24:\d{1,2}:\d{1,2}")].index:
    time = stop_times.loc[index, 'departure_time'].split(":")
    time = ":".join(["00", time[1], time[2]])
    stop_times.loc[index, 'departure_time'] = time
    
for index in stop_times[stop_times.arrival_time.str.match("25:\d{1,2}:\d{1,2}")].index:
    time = stop_times.loc[index, 'arrival_time'].split(":")
    time = ":".join(["01", time[1], time[2]])
    stop_times.loc[index, 'arrival_time'] = time
    
for index in stop_times[stop_times.departure_time.str.match("25:\d{1,2}:\d{1,2}")].index:
    time = stop_times.loc[index, 'departure_time'].split(":")
    time = ":".join(["01", time[1], time[2]])
    stop_times.loc[index, 'departure_time'] = time
    
for index in stop_times[stop_times.arrival_time.str.match("26:\d{1,2}:\d{1,2}")].index:
    time = stop_times.loc[index, 'arrival_time'].split(":")
    time = ":".join(["02", time[1], time[2]])
    stop_times.loc[index, 'arrival_time'] = time
    
for index in stop_times[stop_times.departure_time.str.match("26:\d{1,2}:\d{1,2}")].index:
    time = stop_times.loc[index, 'departure_time'].split(":")
    time = ":".join(["02", time[1], time[2]])
    stop_times.loc[index, 'departure_time'] = time

# %%
stop_times['departure_time'] = pd.to_datetime(stop_times['departure_time'], format='%H:%M:%S').dt.time
stop_times['arrival_time'] = pd.to_datetime(stop_times['arrival_time'], format='%H:%M:%S').dt.time

start = pd.to_datetime("07:00:00", format="%H:%M:%S").time()
end = pd.to_datetime("09:00:00", format="%H:%M:%S").time()
end2 = pd.to_datetime("12:00:00", format="%H:%M:%S").time()

stop_times_7_9 = stop_times[(stop_times['departure_time'] > start) & (stop_times['departure_time'] < end) & 
           (stop_times['arrival_time'] > start) &  (stop_times['arrival_time'] < end)]

stop_times_7_12 = stop_times[(stop_times['departure_time'] > start) & (stop_times['departure_time'] < end) & 
           (stop_times['arrival_time'] > start) &  (stop_times['arrival_time'] < end)]

# %%
trips_flinders_street = trips[trips.trip_headsign=='City (Flinders Street)']
stop_times_trips = pd.merge(left=stop_times, right=trips_flinders_street, on='trip_id')

# %%
stop_times_trips
# Out:
#                               trip_id arrival_time departure_time  stop_id  \
# 0       17182517.T2.2-ALM-B-mjp-1.1.H     04:57:00       04:57:00    19847
# 1       17182517.T2.2-ALM-B-mjp-1.1.H     04:58:00       04:58:00    19848
# 2       17182517.T2.2-ALM-B-mjp-1.1.H     05:00:00       05:00:00    19849
# 3       17182517.T2.2-ALM-B-mjp-1.1.H     05:02:00       05:02:00    19850
# 4       17182517.T2.2-ALM-B-mjp-1.1.H     05:04:00       05:04:00    19851
# ...                               ...          ...            ...      ...
# 191532  17072265.T2.2-WMN-F-mjp-1.3.H     00:22:00       00:22:00    19994
# 191533  17072266.UJ.2-WMN-F-mjp-1.3.H     00:16:00       00:16:00    19991
# 191534  17072266.UJ.2-WMN-F-mjp-1.3.H     00:18:00       00:18:00    19992
# 191535  17072266.UJ.2-WMN-F-mjp-1.3.H     00:19:00       00:19:00    19993
# 191536  17072266.UJ.2-WMN-F-mjp-1.3.H     00:22:00       00:22:00    19994
#
#         stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 0                   1            NaN            0              0
# 1                   2            NaN            0              0
# 2                   3            NaN            0              0
# 3                   4            NaN            0              0
# 4                   5            NaN            0              0
# ...               ...            ...          ...            ...
# 191532              4            NaN            0              0
# 191533              1            NaN            0              0
# 191534              2            NaN            0              0
# 191535              3            NaN            0              0
# 191536              4            NaN            0              0
#
#         shape_dist_traveled       route_id service_id           shape_id  \
# 0                  0.000000  2-ALM-B-mjp-1         T2  2-ALM-B-mjp-1.1.H
# 1                723.017818  2-ALM-B-mjp-1         T2  2-ALM-B-mjp-1.1.H
# 2               1951.735072  2-ALM-B-mjp-1         T2  2-ALM-B-mjp-1.1.H
# 3               2899.073349  2-ALM-B-mjp-1         T2  2-ALM-B-mjp-1.1.H
# 4               3927.090952  2-ALM-B-mjp-1         T2  2-ALM-B-mjp-1.1.H
# ...                     ...            ...        ...                ...
# 191532          3641.811422  2-WMN-F-mjp-1       T2_2  2-WMN-F-mjp-1.3.H
# 191533             0.000000  2-WMN-F-mjp-1       UJ_2  2-WMN-F-mjp-1.3.H
# 191534          1043.072510  2-WMN-F-mjp-1       UJ_2  2-WMN-F-mjp-1.3.H
# 191535          1939.256662  2-WMN-F-mjp-1       UJ_2  2-WMN-F-mjp-1.3.H
# 191536          3641.811422  2-WMN-F-mjp-1       UJ_2  2-WMN-F-mjp-1.3.H
#
#                  trip_headsign  direction_id
# 0       City (Flinders Street)             0
# 1       City (Flinders Street)             0
# 2       City (Flinders Street)             0
# 3       City (Flinders Street)             0
# 4       City (Flinders Street)             0
# ...                        ...           ...
# 191532  City (Flinders Street)             0
# 191533  City (Flinders Street)             0
# 191534  City (Flinders Street)             0
# 191535  City (Flinders Street)             0
# 191536  City (Flinders Street)             0
#
# [191537 rows x 14 columns]

# %%
def travel_min_to_CBD(stop_id):
    times = []
    ts = stop_times_trips[stop_times_trips.stop_id == stop_id].trip_id.unique()
    for t in ts:
        try:
            st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id)].departure_time
            re_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == 19854)].departure_time
            re_time = pd.to_datetime(re_time, format='%H:%M:%S').values[0]
            st_time = pd.to_datetime(st_time, format='%H:%M:%S').values[0]
            times.append(pd.Timedelta(re_time - st_time).seconds / 60)
        except:
            pass
#             print(t)
    return sum(times) / len(times)

# %%
travel_min_to_CBD(19853)
# Out:
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &
# <ipython-input-453-e867401dab97>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   st_time = stop_times_trips[(stop_times_trips.trip_id == t) & (stop_times_trips.stop_id == stop_id) &

# %%
ldep = stop_times['departure_time'] > start
rdep = stop_times['departure_time'] < end
larr = stop_times['arrival_time'] > start
rarr = stop_times['arrival_time'] < end
stop_times[ldep]
# stop_times_7_12 = stop_times[() & (stop_times['departure_time'] < end) & 
#            (stop_times['arrival_time'] > start) &  (stop_times['arrival_time'] < end)]
# Out:
#                               trip_id arrival_time departure_time  stop_id  \
# 34      17182535.T2.2-ALM-B-mjp-1.1.H     07:03:00       07:03:00    19853
# 35      17182541.T2.2-ALM-B-mjp-1.1.H     07:08:00       07:08:00    19847
# 36      17182541.T2.2-ALM-B-mjp-1.1.H     07:09:00       07:09:00    19848
# 37      17182541.T2.2-ALM-B-mjp-1.1.H     07:11:00       07:11:00    19849
# 38      17182541.T2.2-ALM-B-mjp-1.1.H     07:13:00       07:13:00    19850
# ...                               ...          ...            ...      ...
# 390298    17199139.T2.2-ain-mjp-1.4.R     18:15:00       18:15:00    19973
# 390299    17199139.T2.2-ain-mjp-1.4.R     18:19:00       18:19:00    22180
# 390300    17199140.UJ.2-ain-mjp-1.4.R     18:09:00       18:09:00    20028
# 390301    17199140.UJ.2-ain-mjp-1.4.R     18:15:00       18:15:00    19973
# 390302    17199140.UJ.2-ain-mjp-1.4.R     18:19:00       18:19:00    22180
#
#         stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 34                  7            NaN            0              0
# 35                  1            NaN            0              0
# 36                  2            NaN            0              0
# 37                  3            NaN            0              0
# 38                  4            NaN            0              0
# ...               ...            ...          ...            ...
# 390298              4            NaN            0              0
# 390299              5            NaN            0              0
# 390300              1            NaN            0              0
# 390301              4            NaN            0              0
# 390302              5            NaN            0              0
#
#         shape_dist_traveled
# 34              5920.877559
# 35                 0.000000
# 36               723.017818
# 37              1951.735072
# 38              2899.073349
# ...                     ...
# 390298          4011.161109
# 390299          5676.741894
# 390300             0.000000
# 390301          4011.161109
# 390302          5676.741894
#
# [354043 rows x 9 columns]

# %%
stop_times_7_12
# Out:
#                               trip_id arrival_time departure_time  stop_id  \
# 34      17182535.T2.2-ALM-B-mjp-1.1.H     07:03:00       07:03:00    19853
# 35      17182541.T2.2-ALM-B-mjp-1.1.H     07:08:00       07:08:00    19847
# 36      17182541.T2.2-ALM-B-mjp-1.1.H     07:09:00       07:09:00    19848
# 37      17182541.T2.2-ALM-B-mjp-1.1.H     07:11:00       07:11:00    19849
# 38      17182541.T2.2-ALM-B-mjp-1.1.H     07:13:00       07:13:00    19850
# ...                               ...          ...            ...      ...
# 390090    17199066.UJ.2-ain-mjp-1.1.H     08:30:00       08:30:00    22180
# 390091    17199066.UJ.2-ain-mjp-1.1.H     08:34:00       08:34:00    19973
# 390092    17199066.UJ.2-ain-mjp-1.1.H     08:41:00       08:41:00    20028
# 390203    17199067.T2.2-ain-mjp-1.3.R     08:57:00       08:57:00    20028
# 390205    17199068.UJ.2-ain-mjp-1.3.R     08:57:00       08:57:00    20028
#
#         stop_sequence  stop_headsign  pickup_type  drop_off_type  \
# 34                  7            NaN            0              0
# 35                  1            NaN            0              0
# 36                  2            NaN            0              0
# 37                  3            NaN            0              0
# 38                  4            NaN            0              0
# ...               ...            ...          ...            ...
# 390090              1            NaN            0              0
# 390091              2            NaN            0              0
# 390092              5            NaN            0              0
# 390203              1            NaN            0              0
# 390205              1            NaN            0              0
#
#         shape_dist_traveled
# 34              5920.877559
# 35                 0.000000
# 36               723.017818
# 37              1951.735072
# 38              2899.073349
# ...                     ...
# 390090             0.000000
# 390091          1665.580785
# 390092          5676.739730
# 390203             0.000000
# 390205             0.000000
#
# [48016 rows x 9 columns]
